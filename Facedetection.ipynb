# %%
import os
import cv2

# Load the pre-trained Haarcascades classifier for face detection
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
def detect_and_save_faces(input_folder, output_folder):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop through each file in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith(('.jpg', '.jpeg', '.png')):  # Check if the file is an image
            # Read the image
            image_path = os.path.join(input_folder, filename)
            img = cv2.imread(image_path)

            # Convert the image to grayscale for face detection
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

            # Detect faces in the image
            faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

            # Check if faces were detected
            if len(faces) > 0:
                # Save the original image with rectangles around detected faces
                img_with_faces = img.copy()
                for (x, y, w, h) in faces:
                    cv2.rectangle(img_with_faces, (x, y), (x+w, y+h), (0, 255, 0), 2)

                output_path = os.path.join(output_folder, f'{filename}_with_faces.jpg')
                cv2.imwrite(output_path, img_with_faces)

                print(f'Faces detected in {filename}. Saved to {output_path}')
            else:
                print(f'No faces detected in {filename}')

# Specify the input and output folders
input_folder = 'OutputFrames/train/Harass3'  # Replace with the path to your input folder
output_folder = 'output_faces/Fighting/Faces2'  # Replace with the path to your output folder

# Call the function to detect faces and save images with faces
detect_and_save_faces(input_folder, output_folder)
# Out:
# No faces detected in frame_1493.jpg
# No faces detected in frame_0955.jpg
# No faces detected in frame_2824.jpg
# No faces detected in frame_2830.jpg
# No faces detected in frame_1487.jpg
# No faces detected in frame_0941.jpg
# Faces detected in frame_0799.jpg. Saved to output_faces/Fighting/Faces2/frame_0799.jpg_with_faces.jpg
# No faces detected in frame_0969.jpg
# No faces detected in frame_2818.jpg
# No faces detected in frame_1450.jpg
# No faces detected in frame_0996.jpg
# No faces detected in frame_2159.jpg
# No faces detected in frame_1336.jpg
# Faces detected in frame_0028.jpg. Saved to output_faces/Fighting/Faces2/frame_0028.jpg_with_faces.jpg
# No faces detected in frame_1322.jpg
# No faces detected in frame_1444.jpg
# No faces detected in frame_0982.jpg
# No faces detected in frame_2165.jpg
# No faces detected in frame_0772.jpg
# Faces detected in frame_0014.jpg. Saved to output_faces/Fighting/Faces2/frame_0014.jpg_with_faces.jpg
# ...
